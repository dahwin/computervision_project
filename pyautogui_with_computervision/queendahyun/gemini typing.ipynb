# %%
import os
import google.generativeai as genai
# If you want to use these lines with pyautogui
import pyautogui
import time
genai.configure(api_key='AIzaSyDTr4kgk7ylJt2cUp69auPK0NIJPbZVWu8')

time.sleep(5)

# Create the model
generation_config = {
  "temperature": 0,
  "top_p": 0.95,
  "top_k": 40,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash-002",
  generation_config=generation_config,
)


prompt = """
wirte some code in pytorch
don't try to write any explaination just write code
"""


chat_session = model.start_chat(
            history=[
            ]
)

response = chat_session.send_message(prompt,stream=True,)


for chunk in response:
    print(chunk.text)

    # pyautogui.typewrite(chunk.text)
# Out:
# ```
# python
# import torch
# import torch.nn as nn
# import torch.optim as optim
#
#
# # Define a simple neural network
# class Net(nn.Module):
#
# def __init__(self):
#         super(Net, self).__init__()
#         self.fc1 = nn.Linear(10, 5)
#
# self.fc2 = nn.Linear(5, 2)
#
#     def forward(self, x):
#         x = torch.relu(self.fc1
# (x))
#         x = self.fc2(x)
#         return x
#
# # Instantiate the network
# net = Net()
#
# # Define loss function and optimizer
# criterion = nn.CrossEntropyLoss()
# optimizer = optim
# .SGD(net.parameters(), lr=0.01)
#
# # Generate some sample data
# inputs = torch.randn(64, 10)
# targets = torch.randint(0, 2, (64,))
#
#
# # Training loop
# for epoch in range(10):
#     optimizer.zero_grad()
#     outputs = net(inputs)
#     loss = criterion(outputs, targets)
#     loss.backward()
#     optimizer.step()
#
# # Print the final loss
# print(loss)
# ```

# %%
import os
import google.generativeai as genai
import pyautogui
import time
import re

import re

def clean_code_blocks(text):
    """Remove code block markers and clean up the text for typing"""
    # Remove triple backticks with or without python, handling multiple lines
    cleaned = re.sub(r'```(?:python)?\s*', '', text)
    # Remove standalone "python" at the start of the text
    cleaned = re.sub(r'^python\s*\n', '', cleaned, flags=re.MULTILINE)
    # Remove any trailing backticks and whitespace
    cleaned = cleaned.strip('`').strip()
    return cleaned

def clean_code_blocks(text):
    t = """```"""
    if t in text:
        text = text.split(t, 1)[1]
        
    t = """python"""
    if t in text:
        text = text.split(t, 1)[1]
        
    return text
import re


def clean_code_blocks(text):
    # Define a regex pattern to match ```python and the closing ```
    pattern = r"```(?:python)?(.*?)```"
    
    # Use re.sub to replace the matched code blocks with just the content inside them
    cleaned_text = re.sub(pattern, r"\1", text, flags=re.DOTALL)
    
    # Remove any additional ``` that might have been left
    cleaned_text = re.sub(r"```", "", cleaned_text)
    # Remove any additional ``` that might have been left
    cleaned_text = re.sub(r"python", "", cleaned_text)
    return cleaned_text


# Configure the model
genai.configure(api_key='AIzaSyDTr4kgk7ylJt2cUp69auPK0NIJPbZVWu8')
time.sleep(5)

# Create the model with configuration
generation_config = {
    "temperature": 0,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    # model_name="gemini-1.5-flash-002",
    # model_name="gemini-1.5-pro-002",
    generation_config=generation_config,
)

prompt = """
write some code in pytorch don't try to write any explaination just write code
"""

prompt = """
write some code in matplotlib for beautfiul visualization! don't try to write any explaination just write code
"""
# prompt = """
# write a beautiful pyside6 ui with color css gredient!
# full functional youtube like ui!
# don't try to write any explaination just write code
# """
prompt = """
write a paragraph about tree in 1000 word
"""
# Start chat and get response
chat_session = model.start_chat(history=[])
response = chat_session.send_message(prompt, stream=True)

# Process and type each chunk
for chunk in response:
    text = chunk.text
    text = clean_code_blocks(text)
    print(text)  # For verification
    pyautogui.typewrite(text)
# Out:
# In the tapestry of nature's artistry, trees stand as majestic sentinels,
#  their towering presence a testament to the enduring power of life. From the towering redwoods that pierce the heavens to the delicate aspen groves that shimmer in the breeze,
#  trees are an integral part of our planet's ecosystems, providing sustenance, shelter, and a sense of wonder to all who behold them.
#
# Their roots, like intricate tapestries woven into the earth, anchor them firmly in the ground, drawing nourishment from the soil and providing stability against the relentless forces of nature. Their
#  trunks, sturdy and resilient, rise skyward, supporting a vast network of branches that spread out like an intricate canopy. This verdant crown intercepts sunlight, converting it into energy through the process of photosynthesis, the lifeblood of the forest.
#
# Trees are havens for a myriad of creatures. Birds build their nests amidst their branches, their songs filling the air with a symphony of melodies. Squirrels scamper along their trunks, their playful antics adding a touch of whimsy to the forest. Insects flit and flutter among their leaves, pollinating flowers and contributing to the delicate balance of the ecosystem.
#
# Beyond their ecological significance, trees hold
#  a profound cultural and spiritual value. In many indigenous cultures, trees are revered as sacred beings, believed to possess spirits that guide and protect the community. They are often the focal point of rituals and ceremonies, connecting people to the natural world and to their ancestors.
#
# In urban environments, trees provide respite from the hustle and bustle of city life. Their leafy canopies offer shade from the scorching sun, while their rustling leaves create a soothing ambiance that calms the mind and soothes the soul. They line streets, creating verdant corridors that enhance the beauty of our cities and improve air quality.
#
# Trees are living monuments to the passage of time. Their growth rings, etched into their trunks, tell the story of their long lives, bearing witness to droughts, storms, and seasons of abundance. They have stood as silent observers of human history, their presence a reminder of our own mortality and the interconnectedness of all living things.
#
# As we face the challenges of climate change and environmental degradation, trees have become more important than ever. They act as carbon sinks, absorbing carbon dioxide from the atmosphere and helping to mitigate the effects of global warming. Their root systems help to prevent soil erosion and protect watersheds, ensuring the availability of clean water for future generations.
#
# Protecting and preserving our trees
#  is essential for the health of our planet and the well-being of all who inhabit it. By planting trees, reducing deforestation, and implementing sustainable forestry practices, we can ensure that these majestic giants continue to grace our world for centuries to come.
#
# In the words of the renowned naturalist John Muir, "The world is too much with us; late and soon, / Getting and spending, we lay waste our powers;— / Little we see in Nature that is ours; / We have given our hearts away, a sordid boon!" May we all strive to reconnect with the natural world, to appreciate the beauty and wonder of trees, and to work together to protect these invaluable gifts for generations to come.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and a set of subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot the data on the first subplot
axs[0, 0].plot(x, y, color='blue', linewidth=2)
axs[0, 0].set_title('Sine Wave')

# Plot a histogram on the second subplot
axs[0, 1].hist(np.random.randn(100), bins=20, color='green', alpha=0.5)
axs[0, 1].set_title('Histogram')

# Plot a scatter plot on the third subplot
axs[1, 0].scatter(x, y, color='red', s=50)
axs[1, 0].set_title('Scatter Plot')

# Plot a bar chart on the fourth subplot
axs[1, 1].bar(x, y, color='purple', width=0.5)
axs[1, 1].set_title('Bar Chart')

# Set the overall title of the figure
fig.suptitle('Beautiful Visualization with Matplotlib')

# Show the figure
plt.show()

# %%
import re

def clean_code_blocks(text):
    # Remove code block markers and language specifiers
    cleaned_text = re.sub(r'```\s*(?:python)?\s*\n', '', text)
    # Remove any leading/trailing whitespace
    cleaned_text = cleaned_text.strip()
    
    return cleaned_text

# Example usage
text = """
```
python
import torch
import torch.nn as nn
import torch.optim as optim


# Define a simple neural network
class Net(nn.Module):
    
def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(10, 2
0)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(20, 1)

    def
 forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# Instantiate the network
net =
 Net()

# Define loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(net.parameters(), lr=0.01)

# Generate some sample data
inputs = torch.randn(
64, 10)
targets = torch.randn(64, 1)

# Training loop
for epoch in range(100):
    optimizer.zero_grad()
    outputs = net(inputs)
    loss = criterion(outputs, targets)
    loss.
backward()
    optimizer.step()

# Print the final loss
print(loss)"""

cleaned_text = clean_code_blocks(text)
print("Original text:")
print(text)
print("\nCleaned text:")
print(cleaned_text)
# Out:
# Original text:
#
# ```
# python
# import torch
# import torch.nn as nn
# import torch.optim as optim
#
#
# # Define a simple neural network
# class Net(nn.Module):
#
# def __init__(self):
#         super(Net, self).__init__()
#         self.fc1 = nn.Linear(10, 2
# 0)
#         self.relu = nn.ReLU()
#         self.fc2 = nn.Linear(20, 1)
#
#     def
#  forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         return x
#
# # Instantiate the network
# net =
#  Net()
#
# # Define loss function and optimizer
# criterion = nn.MSELoss()
# optimizer = optim.SGD(net.parameters(), lr=0.01)
#
# # Generate some sample data
# inputs = torch.randn(
# 64, 10)
# targets = torch.randn(64, 1)
#
# # Training loop
# for epoch in range(100):
#     optimizer.zero_grad()
#     outputs = net(inputs)
#     loss = criterion(outputs, targets)
#     loss.
# backward()
#     optimizer.step()
#
# # Print the final loss
# print(loss)
#
# Cleaned text:
# import torch
# import torch.nn as nn
# import torch.optim as optim
#
#
# # Define a simple neural network
# class Net(nn.Module):
#
# def __init__(self):
#         super(Net, self).__init__()
#         self.fc1 = nn.Linear(10, 2
# 0)
#         self.relu = nn.ReLU()
#         self.fc2 = nn.Linear(20, 1)
#
#     def
#  forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         return x
#
# # Instantiate the network
# net =
#  Net()
#
# # Define loss function and optimizer
# criterion = nn.MSELoss()
# optimizer = optim.SGD(net.parameters(), lr=0.01)
#
# # Generate some sample data
# inputs = torch.randn(
# 64, 10)
# targets = torch.randn(64, 1)
#
# # Training loop
# for epoch in range(100):
#     optimizer.zero_grad()
#     outputs = net(inputs)
#     loss = criterion(outputs, targets)
#     loss.
# backward()
#     optimizer.step()
#
# # Print the final loss
# print(loss)

# %%
t = """```"""
text.split(t, 1)[1]
# Out:
# '\npython\nimport torch\nimport torch.nn as nn\nimport torch.optim as optim\n\n\n# Define a simple neural network\nclass Net(nn.Module):\n    \ndef __init__(self):\n        super(Net, self).__init__()\n        self.fc1 = nn.Linear(10, 2\n0)\n        self.relu = nn.ReLU()\n        self.fc2 = nn.Linear(20, 1)\n\n    def\n forward(self, x):\n        x = self.fc1(x)\n        x = self.relu(x)\n        x = self.fc2(x)\n        return x\n\n# Instantiate the network\nnet =\n Net()\n\n# Define loss function and optimizer\ncriterion = nn.MSELoss()\noptimizer = optim.SGD(net.parameters(), lr=0.01)\n\n# Generate some sample data\ninputs = torch.randn(\n64, 10)\ntargets = torch.randn(64, 1)\n\n# Training loop\nfor epoch in range(100):\n    optimizer.zero_grad()\n    outputs = net(inputs)\n    loss = criterion(outputs, targets)\n    loss.\nbackward()\n    optimizer.step()\n\n# Print the final loss\nprint(loss)'

# %%
    # # Simulate Ctrl+L then Backspace
    # pyautogui.hotkey('ctrl', 'l')  # Select the current line
    # pyautogui.typewrite("")   # Delete the selected line
