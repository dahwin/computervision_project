# %%
import requests
base =  "https://d28a-35-221-210-134.ngrok-free.app"
url = f"{base}/process-image/"
data = {
    "filter_range": "top_right_corner",
    "object": "restore down",
    "close": None,
    "direction": None,
    "n": 1,
    "verify": False
}

response = requests.post(url, json=data)
if response.status_code == 200:
    with open("processed_image.png", "wb") as f:
        f.write(response.content)
    print("Image saved as processed_image.png")
else:
    print(f"Error: {response.json()}")
# Out:
# Image saved as processed_image.png

# %%
import requests
from PIL import Image
import io

base = "https://d28a-35-221-210-134.ngrok-free.app"
url = f"{base}/process-image/"
data = {
    "filter_range": "top_right_corner",
    "object": "scrollbar",
    "close": None,
    "direction": None,
    "n": 1,
    "verify": True
}

response = requests.post(url, json=data)
if response.status_code == 200:
    # Load the image into a PIL Image object
    pil_image = Image.open(io.BytesIO(response.content))
    
else:
    print(f"Error: {response.json()}")
pil_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080>

# %%
import requests
from PIL import Image
import io

base = "https://5f85-34-82-50-25.ngrok-free.app"
url = f"{base}/process-image/"
data = {
    "filter_range": "top_right_corner",
    "object": "scrollbar",
    "close": None,
    "direction": None,
    "n": 1,
    "verify": True
}

response = requests.post(url, json=data)
if response.status_code == 200:
    # Load the image into a PIL Image object
    pil_image = Image.open(io.BytesIO(response.content))
    
else:
    print(f"Error: {response.json()}")
pil_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080>

# %%
import requests
from PIL import Image
import io

base ="https://5f85-34-82-50-25.ngrok-free.app"
url = f"{base}/process-image/"
data = {
    "filter_range": "top_right_corner",
    "object": "extensions icon",
    "close": None,
    "direction": None,
    "n": 1,
    "verify": True
}

response = requests.post(url, json=data)
if response.status_code == 200:
    # Load the image into a PIL Image object
    pil_image = Image.open(io.BytesIO(response.content))
    
else:
    print(f"Error: {response.json()}")
pil_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080>

# %%
import httpx
import asyncio
import nest_asyncio
nest_asyncio.apply()
async def send_image(file_path: str, server_url: str):
    try:
        # Open the image file in binary mode
        async with httpx.AsyncClient() as client:
            with open(file_path, "rb") as f:
                files = {"file": (file_path, f, "image/png")}
                
                # Send POST request
                response = await client.post(server_url, files=files)
                
                # Handle the response
                if response.status_code == 200:
                    print("Response:", response.json())
                else:
                    print("Error:", response.status_code, response.text)
    except Exception as e:
        print(f"An error occurred: {e}")

# Define server URL and file path
base_url = "https://edcc-34-82-50-25.ngrok-free.app"
endpoint = "/process/"
file_path = r"C:\Users\ALL USER\Desktop\2024-03-10 06_21_36-.png"

# Run the asynchronous function
if __name__ == "__main__":
    asyncio.run(send_image(file_path, f"{base_url}{endpoint}"))
# Out:
# Response: {'results': [['(97) YouTube', 'C', 'A', 'youtube.com', 'YouTube', 'BD', 'Search', 'YouTube Home', 'Home', 'All', 'Music', 'TWICE', 'Jennie Kim', 'Shorts', 'Subscriptions', 'You >', 'youtube icon', '3 line icon', 'home icon', '+ icon', 'rotate icon', 'x icon', 'upload icon', 'unknown icon or logo', 'unknown icon or logo', 'home icon', 'arrow left icon', 'arrow left icon', 'computer screen', 'computer screen', 'screenshot', 'computer screen'], ['Q', '+', 'Media theories', 'Electronic components', 'Live', 'Application software', 'Wildlife', 'KHAMOSHYAN', '56M', 'star icon', 'restore down', 'Zoom Video icon logo', 'minus', 'mic icon', 'unknown icon or logo', 'notifications icon', 'search icon', 'unknown icon or logo', 'right curly brace icon', 'square pause icon', 'three dot icon', 'image'], ['Ki Keno Kivabe', 'Tina Kibria', 'RedotPa', 'TWICE', 'JYP Entertainme...', 'Free virtual visa card 5$ Siqnup bonus', '...', 'Redotpay card 5$ Bonus Cancl C<T', ' o f   Redotpay...', 'ONCE4
# ...

# %%
import requests
import time
base = "https://294f-34-172-246-126.ngrok-free.app"
# Define the API endpoint
url = f"{base}/full/"
s = time.time()
# Send a POST request to the /full/ endpoint
try:
    response = requests.post(url)
    response.raise_for_status()  # Raise an exception for HTTP errors

    # Parse the JSON response
    results = response.json()

    # Print the results
    print("Received results from /full/ endpoint:")
    print(results)

except requests.exceptions.RequestException as e:
    print(f"An error occurred while communicating with the API: {e}")
e = time.time()
print(e-s)
# Out:
# Received results from /full/ endpoint:
# ...

# %%
import requests
from PIL import Image
import io
import time

base ="https://8a8f-34-172-246-126.ngrok-free.app"  # Replace with your server address if different
url = f"{base}/fullimg/"

start_time = time.time()

try:
    # Send a POST request to the /fullimg/ endpoint
    response = requests.post(url)
    response.raise_for_status()  # Raise an exception for HTTP errors

    # Load the image directly into PIL
    pil_image = Image.open(io.BytesIO(response.content))

    # Optionally display or process the image
    
    print("Image successfully loaded into PIL format")

except requests.exceptions.RequestException as e:
    print(f"An error occurred while communicating with the API: {e}")

end_time = time.time()
print(f"Elapsed time: {end_time - start_time:.2f} seconds")
pil_image
# Out:
# Image successfully loaded into PIL format
# Elapsed time: 3.59 seconds
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x1080>
