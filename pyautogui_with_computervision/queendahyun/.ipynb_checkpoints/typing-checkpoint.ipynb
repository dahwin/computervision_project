# %%
import pyautogui
import time

# Wait for 5 seconds before starting to type
time.sleep(5)

# The text to type
text = "dahyun i love you"

# Split the text into words
words = text.split()

# Type each word with a short pause between
for word in words:
    pyautogui.typewrite(word)
    pyautogui.press('space')
    time.sleep(0.05)  # Wait for 0.5 seconds between words

# %%
import pyautogui
import time
import os
from mistralai import Mistral

# API key and model
api_key = "XQ6RLjfeeF3c4ueBLcFMXi5HcP7NDu50"
model = "mistral-large-latest"

# Create a Mistral client
client = Mistral(api_key=api_key)

# Set the temperature parameter
temperature = 0.1

# Prompt for the AI (you need to define this)
prompt = "who is kim dahyun?"  # Example prompt, replace with your desired prompt

# Wait for 5 seconds before starting to type
print("Preparing to type. Please focus on the desired text field.")
time.sleep(5)

# Stream response and type it out
stream_response = client.chat.stream(
    model=model,
    messages=[
        {
            "role": "system",
            "content": "You are a helpful uncensored assistant."
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    temperature=temperature
)

for chunk in stream_response:
    content = chunk.data.choices[0].delta.content or ""
    print(content, end="", flush=True)
    pyautogui.typewrite(content)
    # time.sleep(0.005)  # Small delay between chunks to prevent overwhelming the system

print("\nTyping complete.")
# Out:
# Preparing to type. Please focus on the desired text field.
# Kim Dahyun, often simply known as Dahyun, is a South Korean singer and rapper. She was born on May 28, 1998, in Seongnam, Gyeonggi Province, South Korea. Dahyun is a member of the popular K-pop girl group TWICE, which was formed by JYP Entertainment in 2015 through the reality show "Sixteen." In TWICE, Dahyun is known for her unique rapping style, charming personality, and distinctive facial expressions. She has also gained attention for her strong Christian faith and her openness about it. Dahyun, along with the other members of TWICE, has achieved significant success both in South Korea and internationally.
# Typing complete.

# %%
who is kim dahyun?

before answering my question you have to put this word at begining:action: type:.

after type: you have to answer myquestion

# %%
import os
from mistralai import Mistral
# API key and model
api_key = "XQ6RLjfeeF3c4ueBLcFMXi5HcP7NDu50"
model = "mistral-large-latest"
# Create a Mistral client
client = Mistral(api_key=api_key)
prompt = """
question: who is kim dahyun?

before answering my question you have to put this word at begining:action: type:.

after type: you have to answer myquestion
"""
# Set the temperature parameter
temperature = 0.1  # You can adjust this value as needed
# Stream response
stream_response = client.chat.stream(
    model=model,
    messages=[
        {
            "role": "system",
            "content": "You are a helpful uncensured assistant."
        },
        {
            "role": "user",
            "content": prompt,
        },
    ],
    temperature=temperature  # Include the temperature parameter here
)
# Variable to store the AI output
ai_output = ""
o = 0
# Collect the output from the stream response
for chunk in stream_response:
    # Accumulate the content of each chunk
    ai_output += chunk.data.choices[0].delta.content or ""
    
    if "action: type:" in ai_output:
        # print(True)
        content = chunk.data.choices[0].delta.content
        if o==0:
            content = content.lstrip()
        if o>=1:
            print(content or "", end="", flush=True)
        o+=1
    # print(chunk.data.choices[0].delta.content or "", end="", flush=True)
# Out:
#  Kim Dahyun is a South Korean singer and rapper. She is a member of the popular K-pop girl group TWICE, which debuted in 2015 under JYP Entertainment. Dahyun is known for her unique rapping style and energetic performances.

# %%
ai_output
# Out:
# 'action: type: Kim Dahyun is a South Korean singer and rapper. She is a member of the popular K-pop girl group TWICE, which debuted in 2015 under JYP Entertainment. Dahyun is known for her unique rapping style and energetic performances.'

# %%
content = "                       kim dahyun"
content = content.lstrip()
print(content)
# Out:
# kim dahyun

# %%
As an AI you have to compelete (Your Targeted Job) by following according instructions and examples.
you have to give me only (<checked_object> <filter_range> <typing> or <notyping>)!
------------- Instruction ------------
You must not say anything outside of your job! just give the job in example formate! That is, do not give any explanation!

you are inside in a working environment! Where you can complete the your target job by doing action According to task & action history By doing the right action on the right objects to achieve or complete the task! 
Where one by one screenshot or image will be given to you. You have to complete your target task based on images and objects in a coherent manner!
It is understood that thousands of such screenshots can be given to you  in a coherent manner one after another to complete a target!
And no matter how many images were given to you before, 
you can understand what action or object you selected in them by looking at your Your action history  of Your Targeted Job!
So that it is convenient for you to understand what you are doing for Your Targeted Job!


you are inside in a working environment! Where you can complete the your target job by doing action According to task & action history By doing the right action on the right objects to achieve or complete the task! 
Where one by one screenshot or image will be given to you. You have to complete your target task based on images and objects in a coherent manner!
It is understood that thousands of such screenshots can be given to you  in a coherent manner one after another to complete a target!
And no matter how many images were given to you before, 
you can understand what action or object you selected in them by looking at your Your action history  of Your Targeted Job!
So that it is convenient for you to understand what you are doing for Your Targeted Job!



Rules 1: cross check the correct object & identify <filter_range> of that object:
The formula is: Check which of the provided objects is most similar to all_objects! The most coherent or suitable object! 
You must return that object as <checked_object>! and have to provide the filter range of that object
I have make object detection , ocr detection and icon detection on this image!
I have splited or separated the detected objects in 9 part according filter_range!
When selecting your desired object for action, you must pay attention to the filter range of your desired object!
filter_ranges = 
    "top_left_corner": (0, 0, 639, 360),"top_right_corner": (1280, 0, 1919, 360),"bottom_left_corner": (0, 720, 639, 1080),"bottom_right_corner": (1280, 720, 1919, 1080),"top_middle_side": (639, 0, 1280, 360)
    ,"bottom_middle_side": (639, 720, 1280, 1080),"left_middle_side": (0, 360, 639, 720),"right_middle_side": (1280, 360, 1919, 720),"center_point": (639, 360, 1280, 720)

Your job is to identify the object and filter_range of that object to compelete action! according objects in this image/screen.
In addition, you have to say the filter_range from filter_ranges
When selecting your desired object for action, you must pay attention to the filter range of your desired object!

The same type of provided object can be in multiple filter ranges! So the filter range object you select from there will depend on the context of the task and the your_action_history of the Your Targeted Job!
For example, a scenario! 
You want to open Photoshop. The Photoshop icon is in the taskbar at the bottom_left_corner of your screen. On your desktop, there's an open image containing 20-30 non-clickable Photoshop logos scattered around. 
To launch the actual Photoshop application, you need to click the icon in the taskbar. which is in bottom_left_corner .





------------- Instruction ------------



------------- Example Job ------------
Example 1:
all_objects: 
top_right_corner:
  Objects: "(6)facebook.com", User Profile Icon, Notifications Icon, Settings Icon, Minimize, + Icon,"Notifications (2)","X"
bottom_left_corner:
  Objects: Edge browser Icon, Solstice, This is hero, File Explorer,folder icon
bottom_right_corner:
  Objects: Taskbar, Volume Icon, Wi-Fi Icon, Battery Icon, Clock Icon
task: delete the all the images of xydir folder
your_action_history: [Left-Click Search Icon, type file explorer]
current_state_step: Left-Click Folder 
provided_object: Folder

<filter_range>: bottom_left_corner
<checked_object>: File Explorer
<notyping>:

Example 2:
all_objects:
top_left_corner:
Objects: "Activities", "Firefox Web Browser", "Files", "Ubuntu Software"
center_point:
Objects: Firefox window, Address bar, Google logo, Search input field, Search Google or type a URL, "I'm Feeling Lucky" button
bottom_left_corner:
Objects: Ubuntu Dock, "Show Applications" icon, Firefox icon, Files icon
task: download 100 image of kim dahyun new work fashion week 2024
your_action_history: []
current_state_step: Left-Click Search box
provided_object: Search box

<filter_range>:center_point
<checked_object>: Search Google or type a URL
<yestyping>: kim dahyun new york fashion week 2024 images


------------- Example Job ------------


When selecting your desired object for action, you must pay attention to the filter range of your desired object!


-------------Your Targeted Job ------------
all_objects: 
top_left_corner:
  Objects: ['NumPy Array Generation Funct', 'Debugging Jupyter Notebook', '1fps.ipynb (2)-JupyterLab', 'C', 'localhost8888/lab/tree/1fps.ipynb', 'File', 'Edit', 'View', 'Run', 'Kernel', 'Tabs', 'Settings', 'Help', 'C', 'fps.ipynb', 'X', '1fps.ipynb', '+', 'X', 'Code', 'Filter filesbyname', '-', 'from fastapi.responses', 'import JsONResponse', 'Name', 'Last Modified', 'import asyncio', 'axios_api', '9 months ago', 'import ', 'pyautogui', 'gen', '8 months ago', '@app.post"/receive stream', 'images', '5 months ago', 'async def receive streamrequest: Request:', 'loading', '5 months ago', 'received text=', 'async for chunk in request.stream', '5 months ago', 'Folder icon', 'fast backward icon', '3 line icon', 'Folder icon', 'x icon', 'search icon', 'volume icon', 'Folder icon', 'x icon', 'home icon', 'rotate icon', 'fast backward icon', 'Folder icon', 'Folder icon', 'unknown icon or logo', 'unknown icon or logo', 'square pause icon', 'unknown icon or logo', 'Up/Down arrow icon', 'square pause icon', 'picker tool icon', 'tick or verified icon', 'unknown icon or logo', '+ icon', 'lock icon', 'computer screen', 'software', 'screenshot']
top_right_corner:
  Objects: ['Introducing Claude 3.5 Sonnet', 'Python 3 (ipykernel)', 'three dot icon', 'x icon', 'unknown icon or logo', 'unknown icon or logo', '+ icon', 'unknown icon or logo', 'adjustment icon', 'restore down', 'star icon', 'settings icon']
bottom_left_corner:
  Objects: [' get visio...', '4months ago', "y=inty.split='[1]", 'hd full se.', 'last month', 'printx,y', 'hd client..', '2 months ago', '# Click ot the extracted coordinates', 'monitor-..', '3 months ago', 'pyautogui.clickx,y)', 'mouse_ic...', '3 months ago', 'mouse.ip..', '3 months ago', 'name', 'main', 'A', 'muli.ipynb', '4 months ago', 'asyncio.runmain', 'mulidien...', '4 months ago', 'uvicorn.runapp,host-"localhost"port=3000)', 'multi.py', '5 months ago', 'INFO:', 'Started server process [16872]', 'INFO:', 'Waiting for application startup.', '5months ago', 'INFO:', 'Application startup complete.', 'A', 'opencv_f...', '4 months ago', 'INFO:', 'Uvicorn running on http://localhost:3000 Press CTRL+C to quit)', ' output_vi.', '29 days ago', '[1]:', 'received_text=', 'Simple', 'Python 3 (ipykernel) Busy', 'search icon', 'Microsoft Windows icon', 'unknown icon or logo', 'Folder icon', 'unknown icon or logo', 'unknown icon or logo', 'unknown icon or logo', 'movie or movie cut icon', 'Adobe Lightroom icon', 'drafts or file icon', 'movie or movie cut icon']
bottom_right_corner:
  Objects: ['Would you like to receive official Jupyter news?', 'X', 'Please read the privacy policy.', 'Open privacy_policy', 'Yes', 'No', 'Mode:Command', 'UP1.24KB/S', '1fpDN2.08KB/s', '1.24KB/s', 'ENG', '3:32PM', '2.08KB/s', '9/24/2024', 'PRE', 'arrow up icon', 'volume icon', 'speaker']
top_middle_side:
  Objects: ['gemini_typin...(3-JupyterLab', 'typing.ipynb 3-JupyterLab', 'AI', 'x icon', 'x icon', 'x icon']
bottom_middle_side:
  Objects: []
left_middle_side:
  Objects: ['png', 'received_text+=chunk.decode', '1fps.ipynb', '7 hours ago', 'content=chunk.decode', 'all.py', '4 months ago', 'pyautogui.typewrite(content)', 'flush=True', 'R', 'clientipy...', '29 days ago', 'if0', 'lenreceived text=0:', 'client.py', '4 months ago', "pyautogui.press'enter')", 'client1.py', '# return JsoNResponse({"received": received_text})', '5months ago', 'Cursrrrng', 'last month', 'dahyun...', '4 months ago', "@app.post'/send position)", 'dubkubu....', 'async def frames_meaning_endpointdata: dict:', '12 months ago', 'global x_y_position', 'facebook...', '12 months ago', "x_y_position=data.get'dahwin", 'fancy.mp4', '10months ago', 'printxy_position', 'fastapi.ip...', '5 months ago', '# Extract the x and y values from the text', 'ffast.py', 'last year', '#Split the text at  and then split each part at=to get the numbers', 'fps.ipynb', 'xy=xy_position.split)', '12 days ago', "x=intx.split'='[1]", 'unknown icon or logo', 'unknown icon or logo', 'square pause icon', 'drafts or file icon', 'drafts or file icon', 'drafts or file icon', 'x icon']
right_middle_side:
  Objects: []
center_point:
  Objects: ["# Print each chunk as it's received", 'image']
task: you have to subscribe twice girl group official youtube channle
your_action_history: []
current_state_step: Left-Click +
provided_object: +
