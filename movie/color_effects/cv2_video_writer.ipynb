# %%
import cv2
import numpy as np
from moviepy.editor import VideoFileClip, concatenate_videoclips, vfx

# Your video processing code
clip1 = VideoFileClip('fancy.mp4').subclip(0, 3).fx(vfx.fadein, 1).fx(vfx.fadeout, 1)
clip2 = VideoFileClip('feel.mp4').subclip(0, 3).fx(vfx.fadein, 1).fx(vfx.fadeout, 1)

combined = concatenate_videoclips([clip1, clip2])

# Initialize an empty list to store frames
frames = []

# Iterate through the frames and append each frame as a NumPy array
for frame in combined.iter_frames(fps=combined.fps, dtype='uint8'):
    frames.append(frame)

# Convert the list of frames to a NumPy array
combined_array = np.array(frames)

# Convert RGB frames to BGR format
combined_array_bgr = combined_array[:, :, :, ::-1]

# Get video dimensions
height, width, _ = combined_array[0].shape

# Create a VideoWriter object to save the video as an MP4 file
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
output_video = cv2.VideoWriter('dahyuncv2.mp4', fourcc, combined.fps, (width, height))

# Write each frame to the output video
for frame in combined_array_bgr:
    output_video.write(frame)

# Release the output video
output_video.release()

# %%
import cv2
import numpy as np
from moviepy.editor import VideoFileClip, concatenate_videoclips, vfx

# Load the video clips
clip1 = VideoFileClip('fancy.mp4').subclip(0, 6)
clip2 = VideoFileClip('feel.mp4').subclip(0, 6)
def bgr_to_rgb(frame):
    return frame[..., ::-1]  # Reverse BGR to RGB

# Apply the color conversion function and export the video
clip1= clip1.fl_image(bgr_to_rgb)
# Apply the ocean colormap to clip2
def apply_ocean_colormap(frame):
    # Convert the frame to grayscale and then to 8-bit depth
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_frame_8bit = cv2.convertScaleAbs(gray_frame)

    # Apply the ocean colormap
    ocean_colormap_frame = cv2.applyColorMap(gray_frame_8bit, cv2.COLORMAP_OCEAN)

    return ocean_colormap_frame

# Apply the function to each frame in clip2
clip2_with_colormap = clip2.fl_image(apply_ocean_colormap)

# Combine the clips
combined = concatenate_videoclips([clip1, clip2_with_colormap])

# Initialize an empty list to store frames
frames = []

# Iterate through the frames and append each frame as a NumPy array
for frame in combined.iter_frames(fps=combined.fps, dtype='uint8'):
    frames.append(frame)

# Convert the list of frames to a NumPy array
combined_array = np.array(frames)

# Get video dimensions
height, width, _ = combined_array[0].shape

# Create a VideoWriter object to save the video as an MP4 file
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
output_video = cv2.VideoWriter('dahyuncv2.mp4', fourcc, combined.fps, (width, height))

# Write each frame to the output video
for frame in combined_array:
    output_video.write(frame)

# Release the output video
output_video.release()

# %% [markdown]
# # MoviePY

# %%
# %%time
import cv2
import numpy as np
from moviepy.editor import VideoFileClip, concatenate_videoclips, vfx

# Load the video clips
clip1 = VideoFileClip('fancy.mp4').subclip(0, 6)
clip2 = VideoFileClip('feel.mp4').subclip(0, 6)

def bgr_to_rgb(frame):
    return frame[..., ::-1]  # Reverse BGR to RGB

# Apply the color conversion function and export the video
clip1 = clip1.fl_image(bgr_to_rgb)

# Apply the ocean colormap to clip2
def apply_ocean_colormap(frame):
    # Convert the frame to grayscale and then to 8-bit depth
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_frame_8bit = cv2.convertScaleAbs(gray_frame)

    # Apply the ocean colormap
    ocean_colormap_frame = cv2.applyColorMap(gray_frame_8bit, cv2.COLORMAP_OCEAN)

    return ocean_colormap_frame

# Apply the function to each frame in clip2
clip2_with_colormap = clip2.fl_image(apply_ocean_colormap)

# Combine the clips
combined = concatenate_videoclips([clip1, clip2_with_colormap])
combined.write_videofile('moviepy.mp4')
# Out:
# Moviepy - Building video moviepy.mp4.
# MoviePy - Writing audio in moviepyTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video moviepy.mp4
# Moviepy - Done !
# Moviepy - video ready moviepy.mp4
# CPU times: total: 9.91 s
# Wall time: 18.3 s

# %%
import cv2
import numpy as np
from moviepy.editor import VideoFileClip, concatenate_videoclips, vfx
from tqdm import tqdm  # Import tqdm for the progress bar

# Load the video clips
clip1 = VideoFileClip('fancy.mp4').subclip(0, 3)
clip2 = VideoFileClip('feel.mp4').subclip(0, 3)

def bgr_to_rgb(frame):
    return frame[..., ::-1]  # Reverse BGR to RGB

# Apply the color conversion function and export the video
clip1 = clip1.fl_image(bgr_to_rgb)

# Apply the ocean colormap to clip2
def apply_ocean_colormap(frame):
    # Convert the frame to grayscale and then to 8-bit depth
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_frame_8bit = cv2.convertScaleAbs(gray_frame)

    # Apply the ocean colormap
    ocean_colormap_frame = cv2.applyColorMap(gray_frame_8bit, cv2.COLORMAP_OCEAN)

    return ocean_colormap_frame

# Apply the function to each frame in clip2
clip2_with_colormap = clip2.fl_image(apply_ocean_colormap)
clip1 = clip1.fx(vfx.fadein, 1).fx(vfx.fadeout, 1)
clip2_with_colormap = clip2_with_colormap.fx(vfx.fadein, 1).fx(vfx.fadeout, 1)
# Combine the clips
combined = concatenate_videoclips([clip1, clip2_with_colormap])

# Initialize an empty list to store frames
frames = []

# Estimate the total number of frames
total_frames = int(combined.duration * combined.fps)

# Iterate through the frames and append each frame as a NumPy array
for frame in tqdm(combined.iter_frames(fps=combined.fps, dtype='uint8'), total=total_frames):
    frames.append(frame)

# Convert the list of frames to a NumPy array
combined_array = np.array(frames)

# Get video dimensions
height, width, _ = combined_array[0].shape

# Create a VideoWriter object to save the video as an MP4 file
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
output_video = cv2.VideoWriter('dahyuncv2.mp4', fourcc, combined.fps, (width, height))

# Write each frame to the output video
for frame in tqdm(combined_array, total=total_frames):
    output_video.write(frame)

# Release the output video
output_video.release()
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 180/180 [00:01<00:00, 137.59it/s]

# %%
import subprocess
import json
def has_audio(video_file):
  """Check if a video has audio.

  Args:
    video_file: The path to the video file.

  Returns:
    True if the video has audio, False otherwise.
  """
  cmd = ["ffprobe", "-show_streams", "-print_format", "json", video_file]
  output = subprocess.check_output(cmd)
  data = json.loads(output)
  streams = data["streams"]

  for stream in streams:
    if stream["codec_type"] == "audio":
      return True

  return False


if __name__ == "__main__":
  video_file = "dahyuncv2_with_audio.mp4"
  has_audio = has_audio(video_file)
  print(f"The video {video_file} has audio: {has_audio}")
# Out:
# The video dahyuncv2_with_audio.mp4 has audio: True

# %%
# %%time
import cv2
import numpy as np
from moviepy.editor import VideoFileClip, concatenate_videoclips, vfx
from tqdm import tqdm  # Import tqdm for the progress bar
import os
# Load the video clips
clip1 = VideoFileClip('fancy.mp4').subclip(0, 6)
clip2 = VideoFileClip('feel.mp4').subclip(0, 6)

def bgr_to_rgb(frame):
    return frame[..., ::-1]  # Reverse BGR to RGB

# Apply the color conversion function and export the video
clip1 = clip1.fl_image(bgr_to_rgb)

# Apply the ocean colormap to clip2
def apply_ocean_colormap(frame):
    # Convert the frame to grayscale and then to 8-bit depth
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_frame_8bit = cv2.convertScaleAbs(gray_frame)

    # Apply the ocean colormap
    ocean_colormap_frame = cv2.applyColorMap(gray_frame_8bit, cv2.COLORMAP_OCEAN)

    return ocean_colormap_frame

# Apply the function to each frame in clip2
clip2_with_colormap = clip2.fl_image(apply_ocean_colormap)

# Combine the clips
combined = concatenate_videoclips([clip1, clip2_with_colormap])

# Initialize an empty list to store frames and audio
frames = []
audio = []

# Estimate the total number of frames
total_frames = int(combined.duration * combined.fps)

# Iterate through the frames and append each frame as a NumPy array
for frame in tqdm(combined.iter_frames(fps=combined.fps, dtype='uint8'), total=total_frames):
    frames.append(frame)
    audio.append(combined.audio.get_frame(combined.duration * len(frames) / total_frames))

# Convert the list of frames to a NumPy array
combined_array = np.array(frames)

# Get video dimensions
height, width, _ = combined_array[0].shape

# Create a VideoWriter object to save the video as an MP4 file
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
output_video = cv2.VideoWriter('dahyuncv2.mp4', fourcc, combined.fps, (width, height))

# Write each frame to the output video
for frame in tqdm(combined_array, total=total_frames):
    output_video.write(frame)

# Release the output video
output_video.release()

# Combine the audio frames into a NumPy array
audio_array = np.array(audio)

# Save the audio as a WAV file with a constant sample rate (e.g., 44100 Hz)
audio_file = "combined_audio.wav"
combined.audio.to_audiofile(audio_file, codec="pcm_s16le", fps=44100)

# Merge the video and audio
merged_file = "dahyuncv2_with_audio.mp4"
command = f"ffmpeg -i dahyuncv2.mp4 -i {audio_file} -c:v copy -c:a aac -strict experimental -y {merged_file}"
os.system(command)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 360/360 [00:02<00:00, 145.34it/s]
# MoviePy - Writing audio in combined_audio.wav
# MoviePy - Done.
# CPU times: total: 8.02 s
# Wall time: 15 s
# 0

# %%
import cv2
import numpy as np
from moviepy.editor import VideoFileClip, vfx

# Step 1: Set the video filenames
video_filenames = ["fancy.mp4", "feel.mp4", "fancy.mp4", "feel.mp4"]

# Step 2: Create VideoFileClip objects from the videos
video_clips = []
for filename in video_filenames:
    video = VideoFileClip(filename).subclip(0,3)
    video = video.resize(height=1080)
    video = video.set_position(("center", "center"))  # Set video position to center
    video_clips.append(video)

color_list = ['BONE', 'OCEAN', 'none', 'DEEPGREEN']

# Create a list to store the color-graded video clips
color_clips_list = []

# Iterate through video clips and color list
for video_clip, color in zip(video_clips, color_list):
    if color.lower() == 'none':
        
        def bgr_to_rgb(frame):
            return frame[..., ::-1]  # Reverse BGR to RGB
        # Apply bgr_to_rgb function if color is 'none'
        color_clip = video_clip.fl_image(bgr_to_rgb)
    else:
        # Apply apply_colormap function based on the color_list entry
        def apply_colormap(frame):
            # Convert the frame to grayscale and then to 8-bit depth
            gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray_frame_8bit = cv2.convertScaleAbs(gray_frame)
            print(color)
            # Apply the specified colormap from color_list
            colormap = getattr(cv2, f'COLORMAP_{color}')
            colored_frame = cv2.applyColorMap(gray_frame_8bit, colormap)
            

            return colored_frame

        color_clip = video_clip.fl_image(apply_colormap)

    # Add the color-graded clip to the list
    color_clips_list.append(color_clip)

# You can now use color_clips_list for further processing or exporting
import cv2
import numpy as np

# Define the output video filename
output_filename = 'color.mp4'

# Create a VideoWriter object to save the video as an MP4 file
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
fps = 30  # You can adjust the frame rate as needed
height, width, _ = color_clips_list[0].get_frame(0).shape  # Get video dimensions
output_video = cv2.VideoWriter(output_filename, fourcc, fps, (width, height))

# Iterate through color_clips_list and write each frame to the output video
for color_clip in color_clips_list:
    for frame in color_clip.iter_frames(fps=fps, dtype='uint8'):
        output_video.write(frame)

# Release the output video
output_video.release()

# Optional: Convert the video to a compatible codec if needed
# You can use FFmpeg for this purpose:
# command = f"ffmpeg -i {output_filename} -c:v libx264 -crf 23 -c:a aac -strict experimental -y output_final.mp4"
# os.system(command)

# %%
import cv2
import numpy as np
from moviepy.editor import VideoFileClip
from functools import partial

# Step 1: Set the video filenames
video_filenames = ["fancy.mp4", "feel.mp4", "fancy.mp4", "feel.mp4"]

# Step 2: Create VideoFileClip objects from the videos
video_clips = []
for filename in video_filenames:
    video = VideoFileClip(filename).subclip(0, 3)
    video = video.resize(height=1080)
    video = video.set_position(("center", "center"))  # Set video position to center
    video_clips.append(video)

color_list = ['BONE', 'OCEAN', 'none', 'DEEPGREEN', 'HOT', 'COOL', 'PINK',
              'INFERNO', 'CIVIDIS', 'RAINBOW', 'TWILIGHT', 'TURBO', 'BGR2RGB']

# Create a list to store the color-graded video clips
color_clips_list = []

# Define the apply_colormap function
def apply_colormap(frame, color):
    # Convert the frame to grayscale and then to 8-bit depth
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_frame_8bit = cv2.convertScaleAbs(gray_frame)

    # Apply the specified colormap from color_list
    colormap = getattr(cv2, f'COLORMAP_{color}')
    colored_frame = cv2.applyColorMap(gray_frame_8bit, colormap)

    return colored_frame

# Iterate through video clips and color list
for video_clip, color in zip(video_clips, color_list):
    if color.lower() == 'none':
        def bgr_to_rgb(frame):
            return frame[..., ::-1]  # Reverse BGR to RGB
        # Apply bgr_to_rgb function if color is 'none'
        color_clip = video_clip.fl_image(bgr_to_rgb)
    else:
        # Use functools.partial to create a partially applied function
        apply_colormap_partial = partial(apply_colormap, color=color)
        color_clip = video_clip.fl_image(apply_colormap_partial)

    # Add the color-graded clip to the list
    color_clips_list.append(color_clip)



# Define the output video filename
output_filename = 'color.mp4'

# Create a VideoWriter object to save the video as an MP4 file
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
fps = 30  # You can adjust the frame rate as needed
height, width, _ = color_clips_list[0].get_frame(0).shape  # Get video dimensions
output_video = cv2.VideoWriter(output_filename, fourcc, fps, (width, height))

# Iterate through color_clips_list and write each frame to the output video
for color_clip in color_clips_list:
    for frame in color_clip.iter_frames(fps=fps, dtype='uint8'):
        output_video.write(frame)

# Release the output video
output_video.release()

# %%
, 'HOT', 'COOL', 'PINK',
              'INFERNO', 'CIVIDIS', 'RAINBOW', 'TWILIGHT', 'TURBO', 'BGR2RGB'
