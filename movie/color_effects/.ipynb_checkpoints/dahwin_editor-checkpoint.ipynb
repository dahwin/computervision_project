# %% [markdown]
# '''dahyun+darwin= dahwin'''

# %%
# !brew install pango pkg-config
# !apt install libpango1.0-dev pkg-config python3-dev
# !pip install gizeh manimgl youtube-search
from IPython.display import clear_output
clear_output()

# %%
# from youtube_search import YoutubeSearch


# results = YoutubeSearch('dahyun', max_results=5).to_dict()

# for result in results:
#     print(result)
#     print()

# %%
from moviepy.editor import VideoFileClip, clips_array, vfx

clip1 = VideoFileClip("fancy.mp4").margin(10)  # add 10px contour
clip2 = clip1.fx(vfx.mirror_x)
clip3 = clip1.fx(vfx.mirror_y)
# colorx
# clip4 = clip1.fx(vfx.colorx, 0.5)
#supersample fucking useless
# clip4 = clip1.fx(vfx.supersample, d=2, nframes=10)
#accel_decel
# clip4 = clip1.fx(vfx.accel_decel)
# painting
# clip4 = clip1.fx(vfx.painting)
#mask color useless
# clip4 = clip1.fx(vfx.mask_color)
clip4 = clip1.fx(vfx.blackwhite)
final_clip = clips_array([[clip1, clip2],
                          [clip3, clip4]])
final_clip.resize(width=480).write_videofile("my_stack.mp4")
# Out:
# Moviepy - Building video my_stack.mp4.
# MoviePy - Writing audio in my_stackTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video my_stack.mp4
# Moviepy - Done !
# Moviepy - video ready my_stack.mp4

# %%
from IPython.display import Video

video_path = 'my_stack.mp4'
video = Video(video_path, embed=True)
display(video)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips

def cut_video_clips(file_list, subclip_list):
    # Check if the lengths of the file list and subclip list are the same
    if len(file_list) != len(subclip_list):
        raise ValueError("The file list and subclip list must have the same length.")

    clip_list = []

    # Iterate over the file list and subclip list
    for file, subclip in zip(file_list, subclip_list):
        # Load the video clip from the file
        clip = VideoFileClip(file,target_resolution=(1080, 1920))

        # Extract the start and end times from the subclip tuple
        subclip_start, subclip_end = subclip

        # Check if the subclip start and end times are valid
        if subclip_start < 0 or subclip_end > clip.duration or subclip_start >= subclip_end:
            raise ValueError("Invalid subclip duration.")

        # Cut the video clip using the subclip start and end times
        cut_clip = clip.subclip(subclip_start, subclip_end)
        clip_list.append(cut_clip)

    return clip_list

# Example usage
file_list = ['fancy.mp4', 'feel.mp4']  # List of video file names
subclip_list = [(0, 6), (0, 6)]  # List of subclip durations (start and end times)

cut_clips = cut_video_clips(file_list, subclip_list)

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips

def cut_video_clips(file_list, subclip_list):
    # Check if the lengths of the file list and subclip list are the same
    if len(file_list) != len(subclip_list):
        raise ValueError("The file list and subclip list must have the same length.")

    clip_list = []

    # Iterate over the file list and subclip list
    for file, subclip in zip(file_list, subclip_list):
        # Load the video clip from the file
        clip = VideoFileClip(file,target_resolution=(1080, 1920))

        # Extract the start and end times from the subclip tuple
        subclip_start, subclip_end = subclip

        # Check if the subclip start and end times are valid
        if subclip_start < 0 or subclip_end > clip.duration or subclip_start >= subclip_end:
            raise ValueError("Invalid subclip duration.")

        # Cut the video clip using the subclip start and end times
        cut_clip = clip.subclip(subclip_start, subclip_end)
        clip_list.append(cut_clip)

    return clip_list

# Example usage
file_list = ['feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4']  # List of video file names
subclip_list = [(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6)]  # List of subclip durations (start and end times)

more_clips = cut_video_clips(file_list, subclip_list)

# %%
from moviepy.editor import *

clips = more_clips
padding = 2
video_fx_list = [clips[0]]

idx = clips[0].duration - padding
for video in clips[1:]:
    video_fx_list.append(video.set_start(idx).crossfadein(padding))
    idx += video.duration - padding

final_video = CompositeVideoClip(video_fx_list)
final_video.write_videofile('crossfade.mp4', fps=24) # add any remaining params

# %%
from moviepy.editor import *

def create_crossfade_video(clips):
    padding=1
    video_fx_list = [clips[0]]
    idx = clips[0].duration - padding

    for video in clips[1:]:
        video_fx_list.append(video.set_start(idx).crossfadein(padding))
        idx += video.duration - padding

    final_video = CompositeVideoClip(video_fx_list)
    return final_video

final_video = create_crossfade_video(more_clips)

# %%
final_video.write_videofile('output.mp4', fps=30, codec="libx264", audio_codec="aac", bitrate="5000k")
# Out:
# Moviepy - Building video output.mp4.
# MoviePy - Writing audio in outputTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output.mp4
# Moviepy - Done !
# Moviepy - video ready output.mp4

# %%
cut = concatenate_videoclips(cut_clips)
cut.write_videofile('output.mp4', fps=30, codec="libx264", audio_codec="aac", bitrate="5000k")
# Out:
# Moviepy - Building video output.mp4.
# MoviePy - Writing audio in outputTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output.mp4
# Moviepy - Done !
# Moviepy - video ready output.mp4

# %%
from moviepy.editor import VideoFileClip, ImageSequenceClip
import cv2
import numpy as np

def slidein(clip1, clip2, duration):
    frames1 = [frame for frame in clip1.iter_frames()][:-duration]
    duration_frames = [frame for frame in clip1.iter_frames()][-duration:]

    frames2 = [frame for frame in clip2.iter_frames()]

    height, width, _ = frames1[0].shape
    transition_frames = []

    for i in range(duration):
        # Calculate the translation distance based on the frame index
        # For slide-in effect from right, clip1 moves to the left and clip2 comes from the right
        tx = int((width / duration) * i)
        tx_clip1 = -tx
        tx_clip2 = width - tx

        # Apply translation to clip1
        frame_clip1 = cv2.warpAffine(duration_frames[i], np.float32([[1, 0, tx_clip1], [0, 1, 0]]), (width, height))

        # Apply translation to clip2
        frame_clip2 = cv2.warpAffine(frames2[i], np.float32([[1, 0, tx_clip2], [0, 1, 0]]), (width, height))

        alpha = i / duration  # Linearly increasing alpha value

        blend_frame = cv2.addWeighted(frame_clip1, 1 - alpha, frame_clip2, alpha, 0)

        transition_frames.append(blend_frame)

    remaining_frames = frames2[duration:]

    final_frames = frames1 + transition_frames + remaining_frames

    return final_frames



duration = 30
fps = more_clips[0].fps
out1 = ImageSequenceClip(slidein(more_clips[0], more_clips[1], duration),fps=fps)

out2 = ImageSequenceClip(slidein(out1, more_clips[2], duration),fps=fps)
out3 = ImageSequenceClip(slidein(out2, more_clips[3], duration),fps=fps)
out4 = ImageSequenceClip(slidein(out3, more_clips[4], duration),fps=fps)
final_frames = slidein(out4, more_clips[5], duration)
# Get the resolution from the first frame
height, width, _ = final_frames[0].shape


fourcc = cv2.VideoWriter_fourcc(*'mp4v')
output = cv2.VideoWriter('output.mp4', fourcc, fps, (width, height))

for frame in final_frames:
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    output.write(frame)

output.release()

# %%
from moviepy.editor import VideoFileClip, ImageSequenceClip
import cv2
import numpy as np

def slidein(clip1, clip2):
    duration = 30
    frames1 = [frame for frame in clip1.iter_frames()][:-duration]
    duration_frames = [frame for frame in clip1.iter_frames()][-duration:]

    frames2 = [frame for frame in clip2.iter_frames()]

    height, width, _ = frames1[0].shape
    transition_frames = []

    for i in range(duration):
        # Calculate the translation distance based on the frame index
        # For slide-in effect from right, clip1 moves to the left and clip2 comes from the right
        tx = int((width / duration) * i)
        tx_clip1 = -tx
        tx_clip2 = width - tx

        # Apply translation to clip1
        frame_clip1 = cv2.warpAffine(duration_frames[i], np.float32([[1, 0, tx_clip1], [0, 1, 0]]), (width, height))

        # Apply translation to clip2
        frame_clip2 = cv2.warpAffine(frames2[i], np.float32([[1, 0, tx_clip2], [0, 1, 0]]), (width, height))

        alpha = i / duration  # Linearly increasing alpha value

        blend_frame = cv2.addWeighted(frame_clip1, 1 - alpha, frame_clip2, alpha, 0)

        transition_frames.append(blend_frame)

    remaining_frames = frames2[duration:]

    final_frames = frames1 + transition_frames + remaining_frames

    return final_frames



def create_slidein(more_clips):
    fps = more_clips[0].fps

    def create_image_sequence_clip(previous_clip, next_clip):
        return ImageSequenceClip(slidein(previous_clip, next_clip), fps=fps)

    final_clip = more_clips[0]

    for i in range(1, len(more_clips)):
        final_clip = create_image_sequence_clip(final_clip, more_clips[i])

    return final_clip


# final_clip = create_slidein(more_clips)

# final_clip.write_videofile("output.mp4", codec="libx264", fps=final_clip.fps)

# %%
# %time
def combine_clips(more_clips):
    # Load the video clips from the file list and create subclips
    clips = more_clips

    # Apply crossfade and slide-in effects to the clips
    crossfade_clips = create_crossfade_video(clips[:2])
    slidein_clips = create_slidein(clips[2:4])
    crossfade_clips2 = create_crossfade_video(clips[4:6])
    slidein_clips2 = create_slidein(clips[6:8])
    crossfade_clips3 = create_crossfade_video(clips[8:10])
    slidein_clips3 = create_slidein(clips[10:12])
    crossfade_clips4 = create_crossfade_video(clips[12:14])
    slidein_clips4 = create_slidein(clips[14:16])
    crossfade_clips5 = create_crossfade_video(clips[16:18])
    slidein_clips5 = create_slidein(clips[18:20])
    crossfade_clips6 = create_crossfade_video(clips[20:22])
    slidein_clips6 = create_slidein(clips[22:24])

    # Concatenate all the clips
    final_clip = concatenate_videoclips([crossfade_clips, slidein_clips, crossfade_clips2, slidein_clips2,crossfade_clips3,slidein_clips3,crossfade_clips4,slidein_clips4,crossfade_clips5,slidein_clips5,crossfade_clips6,slidein_clips6])

    # Export the final concatenated clip
    final_clip.write_videofile("all.mp4",fps=24, codec="libx264", bitrate="5000k")


combine_clips(more_clips)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Moviepy - Building video all.mp4.
# MoviePy - Writing audio in allTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video all.mp4
# Moviepy - Done !
# Moviepy - video ready all.mp4

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips

def cut_video_clips(file_list, subclip_list):
    # Check if the lengths of the file list and subclip list are the same
    if len(file_list) != len(subclip_list):
        raise ValueError("The file list and subclip list must have the same length.")

    clip_list = []

    # Iterate over the file list and subclip list
    for file, subclip in zip(file_list, subclip_list):
        # Load the video clip from the file
        clip = VideoFileClip(file,target_resolution=(1080, 1920))

        # Extract the start and end times from the subclip tuple
        subclip_start, subclip_end = subclip

        # Check if the subclip start and end times are valid
        if subclip_start < 0 or subclip_end > clip.duration or subclip_start >= subclip_end:
            raise ValueError("Invalid subclip duration.")

        # Cut the video clip using the subclip start and end times
        cut_clip = clip.subclip(subclip_start, subclip_end)
        clip_list.append(cut_clip)

    return clip_list

# Example usage
file_list = ['feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4','feel.mp4','black_test.mp4', 'cv2imagesfacny.mp4','fancy.mp4','cv2imagesfacny.mp4','feel.mp4']  # List of video file names
subclip_list = [(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6),(0, 6), (0, 6),(0, 6), (0, 6),(0, 6),(0, 6)]  # List of subclip durations (start and end times)

more_clips = cut_video_clips(file_list, subclip_list)

# %%
def combine_clips(more_clips):
    # Load the video clips from the file list and create subclips
    clips = more_clips

    # Apply crossfade and slide-in effects to the clips
    crossfade_clips = create_crossfade_video(clips[:2])
    slidein_clips = create_slidein(clips[2:4])
    crossfade_clips2 = create_crossfade_video(clips[4:6])
    slidein_clips2 = create_slidein(clips[6:8])
    crossfade_clips3 = create_crossfade_video(clips[8:10])
    slidein_clips3 = create_slidein(clips[10:12])
    crossfade_clips4 = create_crossfade_video(clips[12:14])
    slidein_clips4 = create_slidein(clips[14:16])
    crossfade_clips5 = create_crossfade_video(clips[16:18])
    slidein_clips5 = create_slidein(clips[18:20])
    crossfade_clips6 = create_crossfade_video(clips[20:22])
    slidein_clips6 = create_slidein(clips[22:24])
    crossfade_clips7 = create_crossfade_video(clips[24:26])
    slidein_clips7 = create_slidein(clips[26:28])
    crossfade_clips8 = create_crossfade_video(clips[28:30])
    slidein_clips8 = create_slidein(clips[30:32])
    crossfade_clips9 = create_crossfade_video(clips[32:34])
    slidein_clips9 = create_slidein(clips[34:36])
    crossfade_clips10 = create_crossfade_video(clips[36:38])
    slidein_clips10 = create_slidein(clips[38:40])
    crossfade_clips11 = create_crossfade_video(clips[40:42])
    slidein_clips11 = create_slidein(clips[42:44])
    crossfade_clips12 = create_crossfade_video(clips[44:46])
    slidein_clips12 = create_slidein(clips[46:48])

    # Concatenate all the clips
    final_clip = concatenate_videoclips([crossfade_clips, slidein_clips, crossfade_clips2, slidein_clips2,crossfade_clips3,slidein_clips3,crossfade_clips4,slidein_clips4,crossfade_clips5,slidein_clips5,crossfade_clips6,slidein_clips6,crossfade_clips7,slidein_clips7,crossfade_clips8,slidein_clips8,crossfade_clips9,slidein_clips9,crossfade_clips10,slidein_clips10,crossfade_clips11, slidein_clips11,crossfade_clips12,slidein_clips12])

    # Export the final concatenated clip
    final_clip.write_videofile("output.mp4", codec="libx264", bitrate="5000k")


combine_clips(more_clips)

# %%
import psutil

# Get system memory information
memory = psutil.virtual_memory()

# Retrieve the total amount of RAM in bytes
total_ram = memory.total

# Convert the total RAM to a human-readable format
total_ram_gb = total_ram / (1024 ** 3)

# Print the total RAM
print(f"Total RAM: {total_ram_gb:.2f} GB")
# Out:
# Total RAM: 7.95 GB
